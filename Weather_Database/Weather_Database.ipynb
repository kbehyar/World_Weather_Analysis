# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mount isa
# Processing Record 2 of Set 1 | gavle
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | kharan
# Processing Record 5 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 1 | nisia floresta
# Processing Record 7 of Set 1 | chapais
# Processing Record 8 of Set 1 | souillac
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | cabo san lucas
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | tasiilaq
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | yumen
# Processing Record 19 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 20 of Set 1 | werda
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | lompoc
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | rawson
# Processing Record 25 of Set 1 | bethel
# Processing Record 26 of Set 1 | vila
# Processing Record 27 of Set 1 | kathmandu
# Processing Record 28 of Set 1 | la ronge
# Processing Record 29 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 30 of Set 1 | aklavik
# Processing Record 31 of Set 1 | jiwani
# Processing Record 32 of Set 1 | santa marta
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | opuwo
# Processing Record 35 of Set 1 | santa maria
# Processing Record 36 of Set 1 | provideniya
# Processing Record 37 of Set 1 | borba
# Processing Record 38 of Set 1 | eenhana
# Processing Record 39 of Set 1 | katherine
# Processing Record 40 of Set 1 | cape town
# Processing Record 41 of Set 1 | bunia
# Processing Record 42 of Set 1 | ware
# Processing Record 43 of Set 1 | bluff
# Processing Record 44 of Set 1 | nadvoitsy
# Processing Record 45 of Set 1 | guangshui
# Processing Record 46 of Set 1 | tazovskiy
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | saskylakh
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | riyadh
# Processing Record 2 of Set 2 | namibe
# Processing Record 3 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | faanui
# Processing Record 6 of Set 2 | vagur
# Processing Record 7 of Set 2 | liapades
# City not found. Skipping...
# Processing Record 8 of Set 2 | chantada
# Processing Record 9 of Set 2 | punta cardon
# Processing Record 10 of Set 2 | saldanha
# Processing Record 11 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 2 | maniitsoq
# Processing Record 13 of Set 2 | hervey bay
# Processing Record 14 of Set 2 | kutum
# Processing Record 15 of Set 2 | marsa matruh
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | suzun
# Processing Record 18 of Set 2 | mahibadhoo
# Processing Record 19 of Set 2 | quatre cocos
# Processing Record 20 of Set 2 | pevek
# Processing Record 21 of Set 2 | udachnyy
# Processing Record 22 of Set 2 | tiksi
# Processing Record 23 of Set 2 | lingao
# Processing Record 24 of Set 2 | zhigansk
# Processing Record 25 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 2 | kysyl-syr
# Processing Record 27 of Set 2 | hobart
# Processing Record 28 of Set 2 | vaini
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | alta floresta
# Processing Record 31 of Set 2 | chernyshevskiy
# Processing Record 32 of Set 2 | punta arenas
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | iqaluit
# Processing Record 35 of Set 2 | rikitea
# Processing Record 36 of Set 2 | college
# Processing Record 37 of Set 2 | anadyr
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | narsaq
# Processing Record 40 of Set 2 | angoche
# Processing Record 41 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 2 | mitsamiouli
# Processing Record 43 of Set 2 | hithadhoo
# Processing Record 44 of Set 2 | levelland
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | clyde river
# Processing Record 47 of Set 2 | trairi
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | chuy
# Processing Record 50 of Set 2 | nanortalik
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | cherskiy
# Processing Record 3 of Set 3 | olafsvik
# Processing Record 4 of Set 3 | tuktoyaktuk
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | dunedin
# Processing Record 7 of Set 3 | yayva
# Processing Record 8 of Set 3 | longyearbyen
# Processing Record 9 of Set 3 | tacoronte
# Processing Record 10 of Set 3 | sakakah
# Processing Record 11 of Set 3 | westport
# Processing Record 12 of Set 3 | banda aceh
# Processing Record 13 of Set 3 | ambovombe
# Processing Record 14 of Set 3 | leningradskiy
# Processing Record 15 of Set 3 | tashla
# Processing Record 16 of Set 3 | owase
# Processing Record 17 of Set 3 | haibowan
# City not found. Skipping...
# Processing Record 18 of Set 3 | vestmannaeyjar
# Processing Record 19 of Set 3 | imbituba
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | antipino
# Processing Record 22 of Set 3 | coihaique
# Processing Record 23 of Set 3 | mezen
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | springdale
# Processing Record 26 of Set 3 | belfast
# Processing Record 27 of Set 3 | fort nelson
# Processing Record 28 of Set 3 | bayji
# Processing Record 29 of Set 3 | saint-francois
# Processing Record 30 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 3 | alanya
# Processing Record 32 of Set 3 | jiuquan
# Processing Record 33 of Set 3 | pandan
# Processing Record 34 of Set 3 | port alfred
# Processing Record 35 of Set 3 | ancud
# Processing Record 36 of Set 3 | georgetown
# Processing Record 37 of Set 3 | yafran
# Processing Record 38 of Set 3 | vila franca do campo
# Processing Record 39 of Set 3 | bousso
# Processing Record 40 of Set 3 | upernavik
# Processing Record 41 of Set 3 | geraldton
# Processing Record 42 of Set 3 | alofi
# Processing Record 43 of Set 3 | cayenne
# Processing Record 44 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 3 | kenai
# Processing Record 46 of Set 3 | muli
# Processing Record 47 of Set 3 | atuona
# Processing Record 48 of Set 3 | hanko
# Processing Record 49 of Set 3 | lubumbashi
# Processing Record 50 of Set 3 | ilulissat
# Processing Record 1 of Set 4 | fabiansebestyen
# Processing Record 2 of Set 4 | maryanovka
# City not found. Skipping...
# Processing Record 3 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 4 | pangai
# Processing Record 5 of Set 4 | thompson
# Processing Record 6 of Set 4 | erzurum
# Processing Record 7 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 4 | kattivakkam
# Processing Record 9 of Set 4 | waipawa
# Processing Record 10 of Set 4 | kavieng
# Processing Record 11 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 4 | puerto ayora
# Processing Record 13 of Set 4 | taoudenni
# Processing Record 14 of Set 4 | balakhta
# Processing Record 15 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 4 | otavi
# Processing Record 17 of Set 4 | rudbar
# Processing Record 18 of Set 4 | north battleford
# Processing Record 19 of Set 4 | acapulco
# Processing Record 20 of Set 4 | bengkulu
# Processing Record 21 of Set 4 | bitlis
# Processing Record 22 of Set 4 | teknaf
# Processing Record 23 of Set 4 | cidreira
# Processing Record 24 of Set 4 | takab
# Processing Record 25 of Set 4 | guhagar
# Processing Record 26 of Set 4 | port elizabeth
# Processing Record 27 of Set 4 | portland
# Processing Record 28 of Set 4 | honiara
# Processing Record 29 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 4 | syntul
# Processing Record 31 of Set 4 | nome
# Processing Record 32 of Set 4 | malanje
# Processing Record 33 of Set 4 | airai
# Processing Record 34 of Set 4 | johnstown
# Processing Record 35 of Set 4 | snasa
# Processing Record 36 of Set 4 | grindavik
# Processing Record 37 of Set 4 | codrington
# Processing Record 38 of Set 4 | saint-philippe
# Processing Record 39 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | fort saint john
# City not found. Skipping...
# Processing Record 42 of Set 4 | norman wells
# Processing Record 43 of Set 4 | metro
# Processing Record 44 of Set 4 | beya
# Processing Record 45 of Set 4 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 4 | haines junction
# Processing Record 47 of Set 4 | avera
# Processing Record 48 of Set 4 | benton harbor
# Processing Record 49 of Set 4 | margate
# Processing Record 50 of Set 4 | busselton
# Processing Record 1 of Set 5 | kodiak
# Processing Record 2 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 3 of Set 5 | kushima
# Processing Record 4 of Set 5 | kade
# Processing Record 5 of Set 5 | torbay
# Processing Record 6 of Set 5 | mutare
# Processing Record 7 of Set 5 | kondinskoye
# Processing Record 8 of Set 5 | mitu
# Processing Record 9 of Set 5 | sisimiut
# Processing Record 10 of Set 5 | vestmanna
# Processing Record 11 of Set 5 | saint-augustin
# Processing Record 12 of Set 5 | sao jose da coroa grande
# Processing Record 13 of Set 5 | talnakh
# Processing Record 14 of Set 5 | alice springs
# Processing Record 15 of Set 5 | brindisi
# Processing Record 16 of Set 5 | rincon
# Processing Record 17 of Set 5 | port-gentil
# Processing Record 18 of Set 5 | padang
# Processing Record 19 of Set 5 | ponta do sol
# Processing Record 20 of Set 5 | san cristobal
# Processing Record 21 of Set 5 | samarai
# Processing Record 22 of Set 5 | mailsi
# Processing Record 23 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 24 of Set 5 | faya
# Processing Record 25 of Set 5 | ust-tsilma
# Processing Record 26 of Set 5 | ponta delgada
# Processing Record 27 of Set 5 | nokaneng
# Processing Record 28 of Set 5 | baruun-urt
# Processing Record 29 of Set 5 | bairiki
# Processing Record 30 of Set 5 | warri
# Processing Record 31 of Set 5 | ponazyrevo
# Processing Record 32 of Set 5 | rio gallegos
# Processing Record 33 of Set 5 | port lincoln
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | kokkola
# Processing Record 36 of Set 5 | constitucion
# Processing Record 37 of Set 5 | port hardy
# Processing Record 38 of Set 5 | nakamura
# Processing Record 39 of Set 5 | mar del plata
# Processing Record 40 of Set 5 | skagastrond
# City not found. Skipping...
# Processing Record 41 of Set 5 | buchanan
# Processing Record 42 of Set 5 | betong
# Processing Record 43 of Set 5 | sevilla
# Processing Record 44 of Set 5 | noyabrsk
# Processing Record 45 of Set 5 | port macquarie
# Processing Record 46 of Set 5 | bambous virieux
# Processing Record 47 of Set 5 | vila velha
# Processing Record 48 of Set 5 | fiumicino
# Processing Record 49 of Set 5 | lagoa
# Processing Record 50 of Set 5 | bud
# Processing Record 1 of Set 6 | ostrovnoy
# Processing Record 2 of Set 6 | fortuna
# Processing Record 3 of Set 6 | severo-kurilsk
# Processing Record 4 of Set 6 | valera
# Processing Record 5 of Set 6 | beringovskiy
# Processing Record 6 of Set 6 | razgrad
# Processing Record 7 of Set 6 | caravelas
# Processing Record 8 of Set 6 | hasaki
# Processing Record 9 of Set 6 | mana
# Processing Record 10 of Set 6 | santiago del estero
# Processing Record 11 of Set 6 | luderitz
# Processing Record 12 of Set 6 | yulara
# Processing Record 13 of Set 6 | banjar
# Processing Record 14 of Set 6 | guerrero negro
# Processing Record 15 of Set 6 | naryan-mar
# Processing Record 16 of Set 6 | baglung
# Processing Record 17 of Set 6 | lazaro cardenas
# Processing Record 18 of Set 6 | saint-sauveur-des-monts
# Processing Record 19 of Set 6 | ahuimanu
# Processing Record 20 of Set 6 | cozumel
# Processing Record 21 of Set 6 | mayo
# Processing Record 22 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | patu
# Processing Record 24 of Set 6 | steamboat springs
# Processing Record 25 of Set 6 | santo augusto
# Processing Record 26 of Set 6 | berlevag
# Processing Record 27 of Set 6 | brunsbuttel
# Processing Record 28 of Set 6 | camocim
# Processing Record 29 of Set 6 | hajnowka
# Processing Record 30 of Set 6 | dabou
# Processing Record 31 of Set 6 | berbera
# Processing Record 32 of Set 6 | salalah
# Processing Record 33 of Set 6 | egvekinot
# Processing Record 34 of Set 6 | fallon
# Processing Record 35 of Set 6 | parabel
# Processing Record 36 of Set 6 | belyy yar
# Processing Record 37 of Set 6 | barsovo
# Processing Record 38 of Set 6 | srednekolymsk
# Processing Record 39 of Set 6 | sabha
# Processing Record 40 of Set 6 | havre-saint-pierre
# Processing Record 41 of Set 6 | bilma
# Processing Record 42 of Set 6 | kahului
# Processing Record 43 of Set 6 | gladstone
# Processing Record 44 of Set 6 | eureka
# Processing Record 45 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 46 of Set 6 | machiques
# Processing Record 47 of Set 6 | douentza
# Processing Record 48 of Set 6 | nantucket
# Processing Record 49 of Set 6 | severnyy-kospashskiy
# Processing Record 50 of Set 6 | ixtapa
# Processing Record 1 of Set 7 | kirakira
# Processing Record 2 of Set 7 | sioux lookout
# Processing Record 3 of Set 7 | jinchang
# Processing Record 4 of Set 7 | klaksvik
# Processing Record 5 of Set 7 | novichikha
# Processing Record 6 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 7 | yomitan
# City not found. Skipping...
# Processing Record 8 of Set 7 | necochea
# Processing Record 9 of Set 7 | nemuro
# Processing Record 10 of Set 7 | harper
# Processing Record 11 of Set 7 | marsabit
# Processing Record 12 of Set 7 | palencia
# Processing Record 13 of Set 7 | umm lajj
# Processing Record 14 of Set 7 | coquimbo
# Processing Record 15 of Set 7 | mafinga
# Processing Record 16 of Set 7 | nevelsk
# Processing Record 17 of Set 7 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 7 | yamada
# Processing Record 19 of Set 7 | lumphat
# Processing Record 20 of Set 7 | qaqortoq
# Processing Record 21 of Set 7 | cogtong
# Processing Record 22 of Set 7 | rosemount
# Processing Record 23 of Set 7 | katsuura
# Processing Record 24 of Set 7 | benghazi
# Processing Record 25 of Set 7 | baisha
# Processing Record 26 of Set 7 | mount pleasant
# Processing Record 27 of Set 7 | capitao poco
# Processing Record 28 of Set 7 | bathsheba
# Processing Record 29 of Set 7 | darhan
# Processing Record 30 of Set 7 | columbia
# Processing Record 31 of Set 7 | lahij
# Processing Record 32 of Set 7 | kruisfontein
# Processing Record 33 of Set 7 | salina
# Processing Record 34 of Set 7 | guanica
# Processing Record 35 of Set 7 | rio tercero
# Processing Record 36 of Set 7 | laguna
# Processing Record 37 of Set 7 | ewa beach
# Processing Record 38 of Set 7 | beloha
# Processing Record 39 of Set 7 | sur
# Processing Record 40 of Set 7 | coahuayana
# Processing Record 41 of Set 7 | huarmey
# Processing Record 42 of Set 7 | nabire
# Processing Record 43 of Set 7 | orsk
# Processing Record 44 of Set 7 | tura
# Processing Record 45 of Set 7 | carnarvon
# Processing Record 46 of Set 7 | roald
# Processing Record 47 of Set 7 | kpagouda
# City not found. Skipping...
# Processing Record 48 of Set 7 | pisco
# Processing Record 49 of Set 7 | dongying
# Processing Record 50 of Set 7 | safakulevo
# Processing Record 1 of Set 8 | xingyi
# Processing Record 2 of Set 8 | alyangula
# Processing Record 3 of Set 8 | poum
# Processing Record 4 of Set 8 | trelew
# Processing Record 5 of Set 8 | ishigaki
# Processing Record 6 of Set 8 | hlobyne
# Processing Record 7 of Set 8 | chlorakas
# Processing Record 8 of Set 8 | shimoda
# Processing Record 9 of Set 8 | kaeo
# Processing Record 10 of Set 8 | casper
# Processing Record 11 of Set 8 | ibiruba
# Processing Record 12 of Set 8 | nyurba
# Processing Record 13 of Set 8 | kuruman
# Processing Record 14 of Set 8 | dalbandin
# Processing Record 15 of Set 8 | nara
# Processing Record 16 of Set 8 | oum hadjer
# Processing Record 17 of Set 8 | laiagam
# City not found. Skipping...
# Processing Record 18 of Set 8 | nsanje
# Processing Record 19 of Set 8 | broome
# Processing Record 20 of Set 8 | qujing
# Processing Record 21 of Set 8 | hrinova
# Processing Record 22 of Set 8 | pacific grove
# Processing Record 23 of Set 8 | saint george
# Processing Record 24 of Set 8 | kolpashevo
# Processing Record 25 of Set 8 | wanning
# Processing Record 26 of Set 8 | sembakung
# Processing Record 27 of Set 8 | shelburne
# Processing Record 28 of Set 8 | darnah
# Processing Record 29 of Set 8 | baker city
# Processing Record 30 of Set 8 | marawi
# Processing Record 31 of Set 8 | shieli
# Processing Record 32 of Set 8 | havoysund
# Processing Record 33 of Set 8 | vila do maio
# Processing Record 34 of Set 8 | qarchi gak
# Processing Record 35 of Set 8 | dekar
# Processing Record 36 of Set 8 | kapoeta
# Processing Record 37 of Set 8 | dogondoutchi
# Processing Record 38 of Set 8 | flinders
# Processing Record 39 of Set 8 | buritis
# Processing Record 40 of Set 8 | baykit
# Processing Record 41 of Set 8 | henderson
# Processing Record 42 of Set 8 | atkinson
# Processing Record 43 of Set 8 | praia da vitoria
# Processing Record 44 of Set 8 | kalikino
# Processing Record 45 of Set 8 | melo
# Processing Record 46 of Set 8 | bisho
# Processing Record 47 of Set 8 | tilichiki
# Processing Record 48 of Set 8 | labuhan
# Processing Record 49 of Set 8 | sesheke
# Processing Record 50 of Set 8 | chililabombwe
# Processing Record 1 of Set 9 | yining
# Processing Record 2 of Set 9 | yerbogachen
# Processing Record 3 of Set 9 | arraial do cabo
# Processing Record 4 of Set 9 | sidi ali
# Processing Record 5 of Set 9 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 9 | sitka
# Processing Record 7 of Set 9 | ust-maya
# Processing Record 8 of Set 9 | auki
# Processing Record 9 of Set 9 | mantua
# Processing Record 10 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 11 of Set 9 | hualmay
# Processing Record 12 of Set 9 | almansa
# Processing Record 13 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 9 | morwell
# Processing Record 15 of Set 9 | athabasca
# Processing Record 16 of Set 9 | jieshi
# Processing Record 17 of Set 9 | eyl
# Processing Record 18 of Set 9 | severnyy
# Processing Record 19 of Set 9 | rocha
# Processing Record 20 of Set 9 | husavik
# Processing Record 21 of Set 9 | gwadar
# Processing Record 22 of Set 9 | taburi
# City not found. Skipping...
# Processing Record 23 of Set 9 | atasu
# Processing Record 24 of Set 9 | mergui
# City not found. Skipping...
# Processing Record 25 of Set 9 | suntar
# Processing Record 26 of Set 9 | kayerkan
# Processing Record 27 of Set 9 | tautira
# Processing Record 28 of Set 9 | mizque
# Processing Record 29 of Set 9 | amos
# Processing Record 30 of Set 9 | bukachacha
# Processing Record 31 of Set 9 | bonavista
# Processing Record 32 of Set 9 | devyatka
# City not found. Skipping...
# Processing Record 33 of Set 9 | esperance
# Processing Record 34 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 9 | asau
# Processing Record 36 of Set 9 | viedma
# Processing Record 37 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 9 | muskogee
# Processing Record 39 of Set 9 | vao
# Processing Record 40 of Set 9 | boa esperanca
# Processing Record 41 of Set 9 | gueugnon
# Processing Record 42 of Set 9 | biu
# Processing Record 43 of Set 9 | gamba
# Processing Record 44 of Set 9 | muros
# Processing Record 45 of Set 9 | mikhaylovka
# Processing Record 46 of Set 9 | cam ranh
# Processing Record 47 of Set 9 | denpasar
# Processing Record 48 of Set 9 | lakes entrance
# Processing Record 49 of Set 9 | dakar
# Processing Record 50 of Set 9 | pueblo nuevo
# Processing Record 1 of Set 10 | mbuji-mayi
# Processing Record 2 of Set 10 | buenaventura
# Processing Record 3 of Set 10 | victor harbor
# Processing Record 4 of Set 10 | hambantota
# Processing Record 5 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 10 | grand haven
# Processing Record 7 of Set 10 | ternate
# Processing Record 8 of Set 10 | khash
# Processing Record 9 of Set 10 | ukmerge
# Processing Record 10 of Set 10 | tubinskiy
# Processing Record 11 of Set 10 | buariki
# City not found. Skipping...
# Processing Record 12 of Set 10 | hohhot
# Processing Record 13 of Set 10 | tra vinh
# Processing Record 14 of Set 10 | comodoro rivadavia
# Processing Record 15 of Set 10 | fort saint james
# Processing Record 16 of Set 10 | talaya
# Processing Record 17 of Set 10 | tual
# Processing Record 18 of Set 10 | tarauaca
# Processing Record 19 of Set 10 | mount gambier
# Processing Record 20 of Set 10 | bondo
# Processing Record 21 of Set 10 | matam
# Processing Record 22 of Set 10 | kingsland
# Processing Record 23 of Set 10 | morgan city
# Processing Record 24 of Set 10 | tymovskoye
# Processing Record 25 of Set 10 | ryotsu
# Processing Record 26 of Set 10 | liwale
# Processing Record 27 of Set 10 | marystown
# Processing Record 28 of Set 10 | ivangorod
# Processing Record 29 of Set 10 | valdivia
# Processing Record 30 of Set 10 | lavrentiya
# Processing Record 31 of Set 10 | whitehorse
# Processing Record 32 of Set 10 | camacha
# Processing Record 33 of Set 10 | strezhevoy
# Processing Record 34 of Set 10 | inuvik
# Processing Record 35 of Set 10 | xining
# Processing Record 36 of Set 10 | fairbanks
# Processing Record 37 of Set 10 | isangel
# Processing Record 38 of Set 10 | budelsdorf
# Processing Record 39 of Set 10 | dongsheng
# Processing Record 40 of Set 10 | njombe
# Processing Record 41 of Set 10 | altinopolis
# Processing Record 42 of Set 10 | san patricio
# Processing Record 43 of Set 10 | palmer
# Processing Record 44 of Set 10 | mandurah
# Processing Record 45 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 46 of Set 10 | dubna
# Processing Record 47 of Set 10 | emerald
# Processing Record 48 of Set 10 | kagoro
# Processing Record 49 of Set 10 | urdoma
# Processing Record 50 of Set 10 | lexington
# Processing Record 1 of Set 11 | abu samrah
# Processing Record 2 of Set 11 | pandamatenga
# Processing Record 3 of Set 11 | juybar
# Processing Record 4 of Set 11 | villefontaine
# Processing Record 5 of Set 11 | omsukchan
# Processing Record 6 of Set 11 | ngunguru
# Processing Record 7 of Set 11 | komsomolskiy
# Processing Record 8 of Set 11 | nukus
# Processing Record 9 of Set 11 | saint-pierre
# Processing Record 10 of Set 11 | bac lieu
# Processing Record 11 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 12 of Set 11 | albanel
# Processing Record 13 of Set 11 | kimbe
# Processing Record 14 of Set 11 | mangaluru
# Processing Record 15 of Set 11 | puerto baquerizo moreno
# Processing Record 16 of Set 11 | dapaong
# Processing Record 17 of Set 11 | nelson bay
# Processing Record 18 of Set 11 | dubbo
# Processing Record 19 of Set 11 | saint-georges
# Processing Record 20 of Set 11 | sao filipe
# Processing Record 21 of Set 11 | kitui
# Processing Record 22 of Set 11 | vaatsa
# City not found. Skipping...
# Processing Record 23 of Set 11 | nador
# Processing Record 24 of Set 11 | vardo
# Processing Record 25 of Set 11 | rapid valley
# Processing Record 26 of Set 11 | port moresby
# Processing Record 27 of Set 11 | middleton
# Processing Record 28 of Set 11 | lubao
# Processing Record 29 of Set 11 | toora-khem
# Processing Record 30 of Set 11 | ellisras
# Processing Record 31 of Set 11 | quelimane
# Processing Record 32 of Set 11 | carevo
# City not found. Skipping...
# Processing Record 33 of Set 11 | nandyal
# Processing Record 34 of Set 11 | veraval
# Processing Record 35 of Set 11 | boralday
# Processing Record 36 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 11 | moranbah
# Processing Record 38 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 39 of Set 11 | cairns
# Processing Record 40 of Set 11 | coaticook
# Processing Record 41 of Set 11 | ust-koksa
# Processing Record 42 of Set 11 | pinoma
# Processing Record 43 of Set 11 | duki
# Processing Record 44 of Set 11 | pirenopolis
# Processing Record 45 of Set 11 | kloulklubed
# Processing Record 46 of Set 11 | shache
# Processing Record 47 of Set 11 | noumea
# Processing Record 48 of Set 11 | horsham
# Processing Record 49 of Set 11 | rio grande
# Processing Record 50 of Set 11 | sayaxche
# Processing Record 1 of Set 12 | ahipara
# Processing Record 2 of Set 12 | prince rupert
# Processing Record 3 of Set 12 | dauriya
# Processing Record 4 of Set 12 | iralaya
# Processing Record 5 of Set 12 | kavaratti
# Processing Record 6 of Set 12 | maragogi
# Processing Record 7 of Set 12 | herat
# Processing Record 8 of Set 12 | sobolevo
# Processing Record 9 of Set 12 | isla mujeres
# Processing Record 10 of Set 12 | mindelo
# Processing Record 11 of Set 12 | kanker
# Processing Record 12 of Set 12 | ahlen
# Processing Record 13 of Set 12 | bath
# Processing Record 14 of Set 12 | birnin kebbi
# Processing Record 15 of Set 12 | tieli
# Processing Record 16 of Set 12 | kupang
# Processing Record 17 of Set 12 | pangody
# Processing Record 18 of Set 12 | quime
# Processing Record 19 of Set 12 | brae
# Processing Record 20 of Set 12 | ilheus
# Processing Record 21 of Set 12 | aswan
# Processing Record 22 of Set 12 | etchoropo
# Processing Record 23 of Set 12 | neverkino
# Processing Record 24 of Set 12 | ler
# Processing Record 25 of Set 12 | wagar
# Processing Record 26 of Set 12 | meulaboh
# Processing Record 27 of Set 12 | zyryanovsk
# Processing Record 28 of Set 12 | hamilton
# Processing Record 29 of Set 12 | gualeguaychu
# Processing Record 30 of Set 12 | verkhoyansk
# Processing Record 31 of Set 12 | puerto quijarro
# Processing Record 32 of Set 12 | san jose
# Processing Record 33 of Set 12 | chihuahua
# Processing Record 34 of Set 12 | treinta y tres
# Processing Record 35 of Set 12 | sabang
# Processing Record 36 of Set 12 | vanavara
# Processing Record 37 of Set 12 | zhuhai
# Processing Record 38 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 12 | deer lake
# Processing Record 40 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 41 of Set 12 | port augusta
# Processing Record 42 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 43 of Set 12 | wajir
# Processing Record 44 of Set 12 | dores do indaia
# Processing Record 45 of Set 12 | lasa
# Processing Record 46 of Set 12 | zvenigorod
# Processing Record 47 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 48 of Set 12 | novoorsk
# Processing Record 49 of Set 12 | along
# Processing Record 50 of Set 12 | maceio
# Processing Record 1 of Set 13 | soyo
# Processing Record 2 of Set 13 | lokken verk
# City not found. Skipping...
# Processing Record 3 of Set 13 | grand gaube
# Processing Record 4 of Set 13 | bilibino
# Processing Record 5 of Set 13 | dzitbalche
# Processing Record 6 of Set 13 | horasan
# Processing Record 7 of Set 13 | lorengau
# Processing Record 8 of Set 13 | porangatu
# Processing Record 9 of Set 13 | rogun
# City not found. Skipping...
# Processing Record 10 of Set 13 | sorong
# Processing Record 11 of Set 13 | morehead
# Processing Record 12 of Set 13 | pascagoula
# Processing Record 13 of Set 13 | milkovo
# Processing Record 14 of Set 13 | buraydah
# Processing Record 15 of Set 13 | nasirabad
# Processing Record 16 of Set 13 | sungairaya
# Processing Record 17 of Set 13 | sao joao da barra
# Processing Record 18 of Set 13 | brattleboro
# Processing Record 19 of Set 13 | luanda
# Processing Record 20 of Set 13 | vasai
# Processing Record 21 of Set 13 | oussouye
# Processing Record 22 of Set 13 | hingatungan
# Processing Record 23 of Set 13 | price
# Processing Record 24 of Set 13 | benguela
# Processing Record 25 of Set 13 | isiro
# Processing Record 26 of Set 13 | tabou
# Processing Record 27 of Set 13 | flin flon
# Processing Record 28 of Set 13 | batsfjord
# Processing Record 29 of Set 13 | litovko
# Processing Record 30 of Set 13 | maldonado
# Processing Record 31 of Set 13 | winnemucca
# Processing Record 32 of Set 13 | vaitape
# Processing Record 33 of Set 13 | sawtell
# Processing Record 34 of Set 13 | le port
# Processing Record 35 of Set 13 | dali
# Processing Record 36 of Set 13 | baie-comeau
# Processing Record 37 of Set 13 | susangerd
# Processing Record 38 of Set 13 | shingu
# Processing Record 39 of Set 13 | owando
# Processing Record 40 of Set 13 | olinda
# Processing Record 41 of Set 13 | psebay
# Processing Record 42 of Set 13 | kailua
# Processing Record 43 of Set 13 | nizwa
# Processing Record 44 of Set 13 | ukiah
# Processing Record 45 of Set 13 | bhuj
# Processing Record 46 of Set 13 | sanchor
# Processing Record 47 of Set 13 | lupiro
# Processing Record 48 of Set 13 | nouadhibou
# Processing Record 49 of Set 13 | carutapera
# Processing Record 50 of Set 13 | bandar
# Processing Record 1 of Set 14 | wellington
# Processing Record 2 of Set 14 | soria
# Processing Record 3 of Set 14 | christchurch
# Processing Record 4 of Set 14 | port-cartier
# Processing Record 5 of Set 14 | ndele
# Processing Record 6 of Set 14 | lamar
# Processing Record 7 of Set 14 | turbat
# Processing Record 8 of Set 14 | ibra
# Processing Record 9 of Set 14 | guane
# Processing Record 10 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 11 of Set 14 | koungou
# Processing Record 12 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 14 | moron
# Processing Record 14 of Set 14 | susanville
# Processing Record 15 of Set 14 | jalu
# Processing Record 16 of Set 14 | victoria
# Processing Record 17 of Set 14 | khetia
# Processing Record 18 of Set 14 | leninsk
# Processing Record 19 of Set 14 | tocopilla
# Processing Record 20 of Set 14 | palana
# Processing Record 21 of Set 14 | bahia blanca
# Processing Record 22 of Set 14 | villarrica
# Processing Record 23 of Set 14 | sechura
# Processing Record 24 of Set 14 | safaqis
# City not found. Skipping...
# Processing Record 25 of Set 14 | adrar
# Processing Record 26 of Set 14 | green river
# Processing Record 27 of Set 14 | myskhako
# Processing Record 28 of Set 14 | dutlwe
# Processing Record 29 of Set 14 | yarim
# Processing Record 30 of Set 14 | skjervoy
# Processing Record 31 of Set 14 | fethiye
# Processing Record 32 of Set 14 | la tuque
# Processing Record 33 of Set 14 | panalingaan
# Processing Record 34 of Set 14 | alghero
# Processing Record 35 of Set 14 | hede
# Processing Record 36 of Set 14 | surt
# Processing Record 37 of Set 14 | logan lake
# Processing Record 38 of Set 14 | astana
# Processing Record 39 of Set 14 | raga
# Processing Record 40 of Set 14 | ugoofaaru
# Processing Record 41 of Set 14 | kpandae
# Processing Record 42 of Set 14 | mbinga
# Processing Record 43 of Set 14 | bucerias
# Processing Record 44 of Set 14 | tadine
# Processing Record 45 of Set 14 | bida
# Processing Record 46 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 47 of Set 14 | talara
# Processing Record 48 of Set 14 | wynyard
# Processing Record 49 of Set 14 | nehe
# Processing Record 50 of Set 14 | amherst
# Processing Record 1 of Set 15 | mugur-aksy
# Processing Record 2 of Set 15 | bajitpur
# Processing Record 3 of Set 15 | bardiyah
# Processing Record 4 of Set 15 | togur
# Processing Record 5 of Set 15 | sagua la grande
# Processing Record 6 of Set 15 | kununurra
# Processing Record 7 of Set 15 | kiunga
# Processing Record 8 of Set 15 | henties bay
# Processing Record 9 of Set 15 | sistranda
# Processing Record 10 of Set 15 | daru
# Processing Record 11 of Set 15 | fuyu
# Processing Record 12 of Set 15 | touros
# Processing Record 13 of Set 15 | talcahuano
# Processing Record 14 of Set 15 | pital
# Processing Record 15 of Set 15 | maine-soroa
# Processing Record 16 of Set 15 | bilaspur
# Processing Record 17 of Set 15 | gayeri
# Processing Record 18 of Set 15 | aykhal
# Processing Record 19 of Set 15 | yaan
# Processing Record 20 of Set 15 | fare
# Processing Record 21 of Set 15 | palu
# Processing Record 22 of Set 15 | bargarh
# Processing Record 23 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 15 | peace river
# Processing Record 25 of Set 15 | san vicente
# Processing Record 26 of Set 15 | raahe
# Processing Record 27 of Set 15 | devils lake
# Processing Record 28 of Set 15 | aquidauana
# Processing Record 29 of Set 15 | burica
# City not found. Skipping...
# Processing Record 30 of Set 15 | lhuntshi
# City not found. Skipping...
# Processing Record 31 of Set 15 | mogadishu
# Processing Record 32 of Set 15 | nuuk
# Processing Record 33 of Set 15 | chota
# Processing Record 34 of Set 15 | vanimo
# Processing Record 35 of Set 15 | uribia
# Processing Record 36 of Set 15 | obo
# Processing Record 37 of Set 15 | linkou
# Processing Record 38 of Set 15 | luan
# Processing Record 39 of Set 15 | tateyama
# Processing Record 40 of Set 15 | doha
# Processing Record 41 of Set 15 | prado
# Processing Record 42 of Set 15 | dobsina
# Processing Record 43 of Set 15 | karratha
# Processing Record 44 of Set 15 | grenaa
# Processing Record 45 of Set 15 | itoman
# Processing Record 46 of Set 15 | gimli
# Processing Record 47 of Set 15 | balakhninskiy
# Processing Record 48 of Set 15 | port blair
# Processing Record 49 of Set 15 | cremona
# Processing Record 50 of Set 15 | paamiut
# Processing Record 1 of Set 16 | babanusah
# City not found. Skipping...
# Processing Record 2 of Set 16 | kieta
# Processing Record 3 of Set 16 | hailar
# Processing Record 4 of Set 16 | altay
# Processing Record 5 of Set 16 | tucumcari
# Processing Record 6 of Set 16 | sumbuya
# Processing Record 7 of Set 16 | shubarshi
# Processing Record 8 of Set 16 | houma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mount Isa -20.7333  139.5000     62.37        55           5
# 1           Gavle  60.6745   17.1417     52.38        56          98
# 2          Castro -24.7911  -50.0119     66.85        52           0
# 3          Kharan  28.5833   65.4167     83.34        24         100
# 4  Nisia Floresta  -6.0911  -35.2086     86.81        73          75
# 5         Chapais  49.7834  -74.8492     28.18        74         100
# 6        Souillac -20.5167   57.5167     77.38       100          40
# 7            Hilo  19.7297 -155.0900     77.29        95         100
# 8  Cabo San Lucas  22.8909 -109.9124     94.30        23          40
# 9          Avarua -21.2078 -159.7750     78.85        78          51
#
#    Wind Speed Country   Current Description
# 0        0.00      AU             clear sky
# 1        1.01      SE       overcast clouds
# 2        2.04      BR             clear sky
# 3       11.03      PK       overcast clouds
# 4        8.55      BR         broken clouds
# 5       13.80      CA       overcast clouds
# 6        3.44      MU            light rain
# 7        8.05      US  heavy intensity rain
# 8        5.75      MX      scattered clouds
# 9        6.91      CK         broken clouds

# %%
city_data_df = city_data_df[["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]]
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mount Isa      AU -20.7333  139.5000     62.37        55           5
# 1           Gavle      SE  60.6745   17.1417     52.38        56          98
# 2          Castro      BR -24.7911  -50.0119     66.85        52           0
# 3          Kharan      PK  28.5833   65.4167     83.34        24         100
# 4  Nisia Floresta      BR  -6.0911  -35.2086     86.81        73          75
# 5         Chapais      CA  49.7834  -74.8492     28.18        74         100
# 6        Souillac      MU -20.5167   57.5167     77.38       100          40
# 7            Hilo      US  19.7297 -155.0900     77.29        95         100
# 8  Cabo San Lucas      MX  22.8909 -109.9124     94.30        23          40
# 9          Avarua      CK -21.2078 -159.7750     78.85        78          51
#
#    Wind Speed   Current Description
# 0        0.00             clear sky
# 1        1.01       overcast clouds
# 2        2.04             clear sky
# 3       11.03       overcast clouds
# 4        8.55         broken clouds
# 5       13.80       overcast clouds
# 6        3.44            light rain
# 7        8.05  heavy intensity rain
# 8        5.75      scattered clouds
# 9        6.91         broken clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
